# %%
import pandas as pd
import os

# Ruta relativa desde el notebook o script
BASE_DIR = os.path.abspath(os.path.join(os.getcwd(), ".."))  # sube un nivel
CSV_PATH = os.path.join(BASE_DIR, "data", "processed", "spacex_launches_clean_past.csv")

# Leer el CSV
df = pd.read_csv(CSV_PATH)

# Información general
print("📊 Dimensiones del dataset:", df.shape)  # (filas, columnas)
print("\n📌 Columnas:")
print(df.columns.tolist())

# Primeras filas
print("\n🔍 Primeras 5 filas:")
print(df.head())

# Resumen rápido de datos numéricos
print("\n📈 Resumen numérico:")
print(df.describe())

# Revisar valores nulos
print("\n🚫 Valores nulos por columna:")
print(df.isnull().sum())
# Out:
# 📊 Dimensiones del dataset: (179, 31)
#
# 📌 Columnas:
# ['id', 'flight_number', 'name', 'date_utc', 'date', 'year', 'month', 'day', 'quarter', 'weekday', 'is_success', 'rocket_id', 'rocket_name', 'rocket_type', 'stages', 'boosters', 'active', 'first_flight', 'launchpad_id', 'launchpad_name', 'full_name', 'region', 'locality', 'latitude', 'longitude', 'payload_total_mass_kg', 'payload_orbits', 'payload_customers', 'details', 'links.webcast', 'links.article']
#
# 🔍 Primeras 5 filas:
#                          id  flight_number                  name  \
# 0  5eb87cddffd86e000604b32f              6  Falcon 9 Test Flight
# 1  5eb87cdeffd86e000604b330              7                COTS 1
# 2  5eb87cdfffd86e000604b331              8                COTS 2
# 3  5eb87ce0ffd86e000604b332              9                 CRS-1
# 4  5eb87ce1ffd86e000604b333             10                 CRS-2
#
#                     date_utc        date  year  month  day quarter    weekday  \
# ...
